# %% [markdown]
# <a href="https://colab.research.google.com/github/loovcc/Hello-world/blob/Colab/GenAI_ML_HW6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GenAI-ML Homework 6

# %% [markdown]
# In this homework, you will train a model to classify 10 characters in "*BanG Dream! It's MyGO!!!!!*" and "*BanG Dream! Ave Mujica*".
#
# **TODO:**
#
#
# *   Use PyTorch to train a model for image classification
# *   Build **Convolutional Neural Network (CNN)** for image classification
# *   Implement **data-augmentation** for image data
# *   Use **pre-defined model** and **pre-trained weight** and fine-tune it for this task
# *   ~~Make you model available for distinguishing Mortis from Mutsumi~~

# %% [markdown]
# ## Activate GPU

# %% [markdown]
# To enable GPU, please follow these steps:
#
# 1. Click on "Runtime" (or "執行階段") in the header.
# 2. Click on "Change runtime type" (or "變更執行階段類型") in the drop menu.
# 3. Select "T4 GPU" and save. (You can select "A100 GPU" or "V100 GPU" if you have Colab Pro)
# ![EnableGPU.png](data:image/png;base64,...)

# %% [markdown]
# ## Mount Google Drive

# %% [markdown]
# To mount Google Drive, please follow these steps:
#
# 1. Run the next cell.
# 2. Click on "Connect to Google Drive".
# 3. Sign in your account.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import Packages

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms, models
from torch.utils.data import Dataset, DataLoader
import os
import json
from PIL import Image
import numpy as np
import gdown
from tqdm import tqdm
from google.colab import files
import matplotlib.pyplot as plt

# %% [markdown]
# # Download dataset

# %%
# !git clone https://github.com/steven-lunar/GenAI-ML-HW6.git
# %cd ./GenAI-ML-HW6/
# Out:
# Cloning into 'GenAI-ML-HW6'...
# remote: Enumerating objects: 3, done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 3 (from 1)
# Receiving objects: 100% (3/3), 94.76 MiB | 48.47 MiB/s, done.
# /content/GenAI-ML-HW6

# %%
## If the link above is unavaliable or busy, you can try other links here
## Or you just want to download the dataset independently

# !gdown --fuzzy 'https://drive.google.com/file/d/1EayXaoqqEmgt7PUF2EbTdxlmk3vKKcUn/view?usp=sharing'
# !gdown --fuzzy 'https://drive.google.com/file/d/10Y8mKrfhL8gaqICA55ou67A9-8eDOkCb/view?usp=sharing'
# !gdown --fuzzy 'https://drive.google.com/file/d/1pvt0ddY4N4G4nji6i7iBlSjerWZ-YvE8/view?usp=sharing'

# %%
# !unzip GenAI-MLhw6_data.zip
# Out:
# Archive:  GenAI-MLhw6_data.zip
#    creating: test/
#   inflating: test/2058.png
#   inflating: test/1962.png
#   inflating: test/2275.png
#   inflating: test/1945.png
#   inflating: test/2236.png
#   inflating: test/1968.png
#   inflating: test/2180.png
#   inflating: test/2331.png
#   inflating: test/2006.png
#   inflating: test/1953.png
#   inflating: test/2107.png
#   inflating: test/2197.png
#   inflating: test/1980.png
#   inflating: test/2171.png
#   inflating: test/2209.png
#   inflating: test/1889.png
#   inflating: test/2059.png
#   inflating: test/2109.png
#   inflating: test/2005.png
#   inflating: test/2093.png
#   inflating: test/1880.png
#   inflating: test/2152.png
#   inflating: test/2021.png
#   inflating: test/1932.png
#   inflating: test/2258.png
#   inflating: test/2246.png
#   inflating: test/1894.png
#   inflating: test/2187.png
#   inflating: test/2081.png
#   inflating: test/2332.png
#   inflating: test/2136.png
#   inflating: test/2249.png
#   inflating: test/2080.png
#   inflating: test/2091.png
#   inflating: test/2315.png
#   inflating: test/2227.png
#   inflating: test/2198.png
#   inflating: test/1919.png
#   inflating: test/1893.png
#   inflating: test/2042.png
#   inflating: test/2288.png
#   inflating: test/2108.png
#   inflating: test/2053.png
#   inflating: test/1966.png
#   inflating: test/2017.png
#   inflating: test/2342.png
#   inflating: test/2027.png
#   inflating: test/1995.png
#   inflating: test/1977.png
#   inflating: test/2261.png
#   inflating: test/2115.png
#   inflating: test/1939.png
#   inflating: test/2067.png
#   inflating: test/2359.png
#   inflating: test/2032.png
#   inflating: test/2204.png
#   inflating: test/2034.png
#   inflating: test/2159.png
#   inflating: test/1917.png
#   inflating: test/2371.png
#   inflating: test/1979.png
#   inflating: test/2248.png
#   inflating: test/1916.png
#   inflating: test/2263.png
#   inflating: test/2240.png
#   inflating: test/1903.png
#   inflating: test/2173.png
#   inflating: test/2037.png
#   inflating: test/1882.png
#   inflating: test/2025.png
#   inflating: test/2353.png
#   inflating: test/2181.png
#   inflating: test/2008.png
#   inflating: test/1913.png
#   inflating: test/2111.png
#   inflating: test/1963.png
#   inflating: test/2308.png
#   inflating: test/1991.png
#   inflating: test/2220.png
#   inflating: test/2065.png
#   inflating: test/2039.png
#   inflating: test/2360.png
#   inflating: test/2256.png
#   inflating: test/2297.png
#   inflating: test/1943.png
#   inflating: test/2234.png
#   inflating: test/2253.png
#   inflating: test/1987.png
#   inflating: test/2020.png
#   inflating: test/2112.png
#   inflating: test/2070.png
#   inflating: test/2347.png
#   inflating: test/2083.png
#   inflating: test/2327.png
#   inflating: test/2128.png
#   inflating: test/2172.png
#   inflating: test/2287.png
#   inflating: test/2309.png
#   inflating: test/2179.png
#   inflating: test/2168.png
#   inflating: test/2370.png
#   inflating: test/2230.png
#   inflating: test/1960.png
#   inflating: test/1887.png
#   inflating: test/2075.png
#   inflating: test/1998.png
#   inflating: test/2088.png
#   inflating: test/2349.png
#   inflating: test/2279.png
#   inflating: test/2320.png
#   inflating: test/2278.png
#   inflating: test/2316.png
#   inflating: test/1900.png
#   inflating: test/2216.png
#   inflating: test/1897.png
#   inflating: test/2195.png
#   inflating: test/2304.png
#   inflating: test/1975.png
#   inflating: test/2285.png
#   inflating: test/2241.png
#   inflating: test/2156.png
#   inflating: test/2269.png
#   inflating: test/1988.png
#   inflating: test/2009.png
#   inflating: test/1930.png
#   inflating: test/2001.png
#   inflating: test/2190.png
#   inflating: test/1898.png
#   inflating: test/1982.png
#   inflating: test/2064.png
#   inflating: test/2185.png
#   inflating: test/2150.png
#   inflating: test/2266.png
#   inflating: test/2257.png
#   inflating: test/2049.png
#   inflating: test/2155.png
#   inflating: test/2221.png
#   inflating: test/2259.png
#   inflating: test/1970.png
#   inflating: test/2365.png
#   inflating: test/2076.png
#   inflating: test/2118.png
#   inflating: test/2133.png
#   inflating: test/2186.png
#   inflating: test/2149.png
#   inflating: test/1899.png
#   inflating: test/2166.png
#   inflating: test/1909.png
#   inflating: test/2137.png
#   inflating: test/2110.png
#   inflating: test/2061.png
#   inflating: test/1926.png
#   inflating: test/2312.png
#   inflating: test/2153.png
#   inflating: test/2087.png
#   inflating: test/2170.png
#   inflating: test/1908.png
#   inflating: test/2354.png
#   inflating: test/1912.png
#   inflating: test/1994.png
#   inflating: test/1986.png
#   inflating: test/2120.png
#   inflating: test/2201.png
#   inflating: test/1895.png
#   inflating: test/2090.png
#   inflating: test/2104.png
#   inflating: test/2373.png
#   inflating: test/2330.png
#   inflating: test/2176.png
#   inflating: test/2215.png
#   inflating: test/2329.png
#   inflating: test/2073.png
#   inflating: test/2105.png
#   inflating: test/1878.png
#   inflating: test/1935.png
#   inflating: test/2298.png
#   inflating: test/2167.png
#   inflating: test/2310.png
#   inflating: test/2376.png
#   inflating: test/2244.png
#   inflating: test/2040.png
#   inflating: test/2096.png
#   inflating: test/2134.png
#   inflating: test/2272.png
#   inflating: test/1990.png
#   inflating: test/2041.png
#   inflating: test/2024.png
#   inflating: test/2086.png
#   inflating: test/2098.png
#   inflating: test/2160.png
#   inflating: test/2003.png
#   inflating: test/2208.png
#   inflating: test/2322.png
#   inflating: test/2035.png
#   inflating: test/2022.png
#   inflating: test/2321.png
#   inflating: test/2325.png
#   inflating: test/2169.png
#   inflating: test/2232.png
#   inflating: test/1881.png
#   inflating: test/1911.png
#   inflating: test/2132.png
#   inflating: test/2345.png
#   inflating: test/2291.png
#   inflating: test/2243.png
#   inflating: test/2250.png
#   inflating: test/1984.png
#   inflating: test/2085.png
#   inflating: test/1957.png
#   inflating: test/2314.png
#   inflating: test/1907.png
#   inflating: test/2271.png
#   inflating: test/2267.png
#   inflating: test/1888.png
#   inflating: test/2211.png
#   inflating: test/2010.png
#   inflating: test/2303.png
#   inflating: test/2026.png
#   inflating: test/2352.png
#   inflating: test/2139.png
#   inflating: test/2047.png
#   inflating: test/1891.png
#   inflating: test/1983.png
#   inflating: test/1985.png
#   inflating: test/2223.png
#   inflating: test/1892.png
#   inflating: test/1996.png
#   inflating: test/2163.png
#   inflating: test/2333.png
#   inflating: test/2337.png
#   inflating: test/2346.png
#   inflating: test/2028.png
#   inflating: test/2296.png
#   inflating: test/2237.png
#   inflating: test/1879.png
#   inflating: test/2151.png
#   inflating: test/1931.png
#   inflating: test/1964.png
#   inflating: test/1940.png
#   inflating: test/2218.png
#   inflating: test/1942.png
#   inflating: test/2228.png
#   inflating: test/1944.png
#   inflating: test/2231.png
#   inflating: test/2335.png
#   inflating: test/2374.png
#   inflating: test/2350.png
#   inflating: test/2301.png
#   inflating: test/2307.png
#   inflating: test/2164.png
#   inflating: test/2328.png
#   inflating: test/2148.png
#   inflating: test/2224.png
#   inflating: test/2318.png
#   inflating: test/2202.png
#   inflating: test/2268.png
#   inflating: test/2126.png
#   inflating: test/2214.png
#   inflating: test/1946.png
#   inflating: test/2117.png
#   inflating: test/1922.png
#   inflating: test/2369.png
#   inflating: test/2251.png
#   inflating: test/2106.png
#   inflating: test/2368.png
#   inflating: test/2363.png
#   inflating: test/2362.png
#   inflating: test/1976.png
#   inflating: test/2340.png
#   inflating: test/2052.png
#   inflating: test/2019.png
#   inflating: test/2101.png
#   inflating: test/2036.png
#   inflating: test/2343.png
#   inflating: test/1969.png
#   inflating: test/1938.png
#   inflating: test/2002.png
#   inflating: test/2205.png
#   inflating: test/1955.png
#   inflating: test/2255.png
#   inflating: test/1902.png
#   inflating: test/2077.png
#   inflating: test/1905.png
#   inflating: test/2199.png
#   inflating: test/2054.png
#   inflating: test/1934.png
#   inflating: test/1950.png
#   inflating: test/2283.png
#   inflating: test/2225.png
#   inflating: test/2194.png
#   inflating: test/2097.png
#   inflating: test/2131.png
#   inflating: test/2280.png
#   inflating: test/2072.png
#   inflating: test/2358.png
#   inflating: test/1890.png
#   inflating: test/2361.png
#   inflating: test/2302.png
#   inflating: test/2129.png
#   inflating: test/2292.png
#   inflating: test/2142.png
#   inflating: test/2217.png
#   inflating: test/1989.png
#   inflating: test/2147.png
#   inflating: test/2300.png
#   inflating: test/2124.png
#   inflating: test/2305.png
#   inflating: test/2135.png
#   inflating: test/2210.png
#   inflating: test/2069.png
#   inflating: test/1961.png
#   inflating: test/1885.png
#   inflating: test/2344.png
#   inflating: test/2284.png
#   inflating: test/2242.png
#   inflating: test/1915.png
#   inflating: test/2273.png
#   inflating: test/2311.png
#   inflating: test/2174.png
#   inflating: test/2045.png
#   inflating: test/2014.png
#   inflating: test/2188.png
#   inflating: test/2239.png
#   inflating: test/2130.png
#   inflating: test/2323.png
#   inflating: test/2033.png
#   inflating: test/2252.png
#   inflating: test/2183.png
#   inflating: test/2289.png
#   inflating: test/2089.png
#   inflating: test/2015.png
#   inflating: test/2334.png
#   inflating: test/2084.png
#   inflating: test/2260.png
#   inflating: test/2103.png
#   inflating: test/2145.png
#   inflating: test/1967.png
#   inflating: test/2023.png
#   inflating: test/2123.png
#   inflating: test/1936.png
#   inflating: test/2177.png
#   inflating: test/1937.png
#   inflating: test/1951.png
#   inflating: test/2367.png
#   inflating: test/2007.png
#   inflating: test/2189.png
#   inflating: test/2357.png
#   inflating: test/1927.png
#   inflating: test/2175.png
#   inflating: test/2286.png
#   inflating: test/2013.png
#   inflating: test/2066.png
#   inflating: test/1904.png
#   inflating: test/2213.png
#   inflating: test/2264.png
#   inflating: test/2092.png
#   inflating: test/1920.png
#   inflating: test/2031.png
#   inflating: test/1883.png
#   inflating: test/2313.png
#   inflating: test/2122.png
#   inflating: test/2000.png
#   inflating: test/2113.png
#   inflating: test/2018.png
#   inflating: test/2082.png
#   inflating: test/2146.png
#   inflating: test/2078.png
#   inflating: test/1896.png
#   inflating: test/2114.png
#   inflating: test/2282.png
#   inflating: test/2324.png
#   inflating: test/1933.png
#   inflating: test/2057.png
#   inflating: test/1910.png
#   inflating: test/2074.png
#   inflating: test/2299.png
#   inflating: test/2341.png
#   inflating: test/2056.png
#   inflating: test/1992.png
#   inflating: test/2238.png
#   inflating: test/2233.png
#   inflating: test/1993.png
#   inflating: test/1914.png
#   inflating: test/1947.png
#   inflating: test/2306.png
#   inflating: test/1971.png
#   inflating: test/2191.png
#   inflating: test/2319.png
#   inflating: test/2348.png
#   inflating: test/1978.png
#   inflating: test/2247.png
#   inflating: test/2125.png
#   inflating: test/2372.png
#   inflating: test/1959.png
#   inflating: test/1929.png
#   inflating: test/2121.png
#   inflating: test/2366.png
#   inflating: test/2011.png
#   inflating: test/2274.png
#   inflating: test/2207.png
#   inflating: test/2182.png
#   inflating: test/2060.png
#   inflating: test/1958.png
#   inflating: test/2055.png
#   inflating: test/1921.png
#   inflating: test/2222.png
#   inflating: test/2317.png
#   inflating: test/1948.png
#   inflating: test/2161.png
#   inflating: test/2196.png
#   inflating: test/2245.png
#   inflating: test/2235.png
#   inflating: test/2071.png
#   inflating: test/1949.png
#   inflating: test/2158.png
#   inflating: test/2262.png
#   inflating: test/2004.png
#   inflating: test/2295.png
#   inflating: test/2203.png
#   inflating: test/1941.png
#   inflating: test/2102.png
#   inflating: test/2044.png
#   inflating: test/2364.png
#   inflating: test/2377.png
#   inflating: test/2338.png
#   inflating: test/1906.png
#   inflating: test/2143.png
#   inflating: test/1924.png
#   inflating: test/2094.png
#   inflating: test/2050.png
#   inflating: test/2293.png
#   inflating: test/2200.png
#   inflating: test/2375.png
#   inflating: test/1999.png
#   inflating: test/2193.png
#   inflating: test/1965.png
#   inflating: test/1923.png
#   inflating: test/2336.png
#   inflating: test/1981.png
#   inflating: test/2030.png
#   inflating: test/2068.png
#   inflating: test/2206.png
#   inflating: test/2294.png
#   inflating: test/2051.png
#   inflating: test/2154.png
#   inflating: test/2229.png
#   inflating: test/2046.png
#   inflating: test/2355.png
#   inflating: test/1952.png
#   inflating: test/1954.png
#   inflating: test/test.json
#   inflating: test/2192.png
#   inflating: test/1918.png
#   inflating: test/1974.png
#   inflating: test/2254.png
#   inflating: test/2219.png
#   inflating: test/2016.png
#   inflating: test/2277.png
#   inflating: test/2270.png
#   inflating: test/2290.png
#   inflating: test/2184.png
#   inflating: test/2095.png
#   inflating: test/2157.png
#   inflating: test/2048.png
#   inflating: test/2281.png
#   inflating: test/1886.png
#   inflating: test/2099.png
#   inflating: test/2265.png
#   inflating: test/2212.png
#   inflating: test/2226.png
#   inflating: test/2165.png
#   inflating: test/2127.png
#   inflating: test/2140.png
#   inflating: test/2162.png
#   inflating: test/1956.png
#   inflating: test/1925.png
#   inflating: test/2116.png
#   inflating: test/2043.png
#   inflating: test/1928.png
#   inflating: test/2012.png
#   inflating: test/2351.png
#   inflating: test/2276.png
#   inflating: test/2062.png
#   inflating: test/2063.png
#   inflating: test/2141.png
#   inflating: test/1973.png
#   inflating: test/2356.png
#   inflating: test/2178.png
#   inflating: test/2038.png
#   inflating: test/2119.png
#   inflating: test/1884.png
#   inflating: test/2138.png
#   inflating: test/1972.png
#   inflating: test/1901.png
#   inflating: test/2079.png
#   inflating: test/2100.png
#   inflating: test/2029.png
#   inflating: test/1997.png
#   inflating: test/2144.png
#   inflating: test/2326.png
#   inflating: test/2339.png
#    creating: train/
#   inflating: train/53.png
#   inflating: train/1334.png
#   inflating: train/51.png
#   inflating: train/1163.png
#   inflating: train/235.png
#   inflating: train/228.png
#   inflating: train/43.png
#   inflating: train/1098.png
#   inflating: train/723.png
#   inflating: train/223.png
#   inflating: train/1287.png
#   inflating: train/140.png
#   inflating: train/857.png
#   inflating: train/690.png
#   inflating: train/1410.png
#   inflating: train/1142.png
#   inflating: train/1183.png
#   inflating: train/424.png
#   inflating: train/1282.png
#   inflating: train/1191.png
#   inflating: train/663.png
#   inflating: train/604.png
#   inflating: train/111.png
#   inflating: train/1428.png
#   inflating: train/1013.png
#   inflating: train/196.png
#   inflating: train/402.png
#   inflating: train/1240.png
#   inflating: train/1451.png
#   inflating: train/401.png
#   inflating: train/1564.png
#   inflating: train/710.png
#   inflating: train/1189.png
#   inflating: train/294.png
#   inflating: train/112.png
#   inflating: train/1304.png
#   inflating: train/1291.png
#   inflating: train/1418.png
#   inflating: train/1376.png
#   inflating: train/965.png
#   inflating: train/1559.png
#   inflating: train/800.png
#   inflating: train/1389.png
#   inflating: train/1254.png
#   inflating: train/1230.png
#   inflating: train/303.png
#   inflating: train/1107.png
#   inflating: train/1143.png
#   inflating: train/1043.png
#   inflating: train/1014.png
#   inflating: train/1174.png
#   inflating: train/482.png
#   inflating: train/845.png
#   inflating: train/1235.png
#   inflating: train/133.png
#   inflating: train/1453.png
#   inflating: train/1256.png
#   inflating: train/145.png
#   inflating: train/617.png
#   inflating: train/374.png
#   inflating: train/559.png
#   inflating: train/1112.png
#   inflating: train/1180.png
#   inflating: train/109.png
#   inflating: train/730.png
#   inflating: train/1529.png
#   inflating: train/1106.png
#   inflating: train/27.png
#   inflating: train/309.png
#   inflating: train/1101.png
#   inflating: train/714.png
#   inflating: train/1150.png
#   inflating: train/750.png
#   inflating: train/625.png
#   inflating: train/310.png
#   inflating: train/747.png
#   inflating: train/1061.png
#   inflating: train/353.png
#   inflating: train/453.png
#   inflating: train/881.png
#   inflating: train/271.png
#   inflating: train/577.png
#   inflating: train/171.png
#   inflating: train/147.png
#   inflating: train/1515.png
#   inflating: train/436.png
#   inflating: train/1311.png
#   inflating: train/1096.png
#   inflating: train/917.png
#   inflating: train/89.png
#   inflating: train/452.png
#   inflating: train/561.png
#   inflating: train/556.png
#   inflating: train/1168.png
#   inflating: train/495.png
#   inflating: train/127.png
#   inflating: train/713.png
#   inflating: train/403.png
#   inflating: train/385.png
#   inflating: train/953.png
#   inflating: train/65.png
#   inflating: train/243.png
#   inflating: train/1155.png
#   inflating: train/1216.png
#   inflating: train/711.png
#   inflating: train/216.png
#   inflating: train/619.png
#   inflating: train/268.png
#   inflating: train/1273.png
#   inflating: train/1187.png
#   inflating: train/342.png
#   inflating: train/265.png
#   inflating: train/1350.png
#   inflating: train/181.png
#   inflating: train/1188.png
#   inflating: train/1151.png
#   inflating: train/1490.png
#   inflating: train/603.png
#   inflating: train/1321.png
#   inflating: train/1491.png
#   inflating: train/811.png
#   inflating: train/843.png
#   inflating: train/892.png
#   inflating: train/407.png
#   inflating: train/925.png
#   inflating: train/1358.png
#   inflating: train/639.png
#   inflating: train/186.png
#   inflating: train/1400.png
#   inflating: train/447.png
#   inflating: train/932.png
#   inflating: train/1309.png
#   inflating: train/616.png
#   inflating: train/48.png
#   inflating: train/1009.png
#   inflating: train/366.png
#   inflating: train/429.png
#   inflating: train/260.png
#   inflating: train/1407.png
#   inflating: train/47.png
#   inflating: train/1518.png
#   inflating: train/168.png
#   inflating: train/97.png
#   inflating: train/1269.png
#   inflating: train/398.png
#   inflating: train/797.png
#   inflating: train/508.png
#   inflating: train/506.png
#   inflating: train/427.png
#   inflating: train/615.png
#   inflating: train/592.png
#   inflating: train/1342.png
#   inflating: train/463.png
#   inflating: train/1298.png
#   inflating: train/520.png
#   inflating: train/683.png
#   inflating: train/1337.png
#   inflating: train/1109.png
#   inflating: train/728.png
#   inflating: train/1310.png
#   inflating: train/840.png
#   inflating: train/1082.png
#   inflating: train/20.png
#   inflating: train/410.png
#   inflating: train/1486.png
#   inflating: train/661.png
#   inflating: train/373.png
#   inflating: train/1023.png
#   inflating: train/863.png
#   inflating: train/1497.png
#   inflating: train/1203.png
#   inflating: train/224.png
#   inflating: train/803.png
#   inflating: train/1433.png
#   inflating: train/1531.png
#   inflating: train/973.png
#   inflating: train/1459.png
#   inflating: train/935.png
#   inflating: train/989.png
#   inflating: train/1543.png
#   inflating: train/1488.png
#   inflating: train/116.png
#   inflating: train/184.png
#   inflating: train/570.png
#   inflating: train/1208.png
#   inflating: train/1574.png
#   inflating: train/1095.png
#   inflating: train/718.png
#   inflating: train/1045.png
#   inflating: train/701.png
#   inflating: train/736.png
#   inflating: train/660.png
#   inflating: train/1176.png
#   inflating: train/793.png
#   inflating: train/605.png
#   inflating: train/1083.png
#   inflating: train/1059.png
#   inflating: train/880.png
#   inflating: train/542.png
#   inflating: train/1330.png
#   inflating: train/890.png
#   inflating: train/923.png
#   inflating: train/1121.png
#   inflating: train/1137.png
#   inflating: train/911.png
#   inflating: train/1567.png
#   inflating: train/193.png
#   inflating: train/1570.png
#   inflating: train/1414.png
#   inflating: train/584.png
#   inflating: train/1103.png
#   inflating: train/657.png
#   inflating: train/1195.png
#   inflating: train/434.png
#   inflating: train/371.png
#   inflating: train/1312.png
#   inflating: train/83.png
#   inflating: train/1119.png
#   inflating: train/653.png
#   inflating: train/819.png
#   inflating: train/1465.png
#   inflating: train/1464.png
#   inflating: train/391.png
#   inflating: train/1132.png
#   inflating: train/910.png
#   inflating: train/1338.png
#   inflating: train/1466.png
#   inflating: train/589.png
#   inflating: train/194.png
#   inflating: train/901.png
#   inflating: train/431.png
#   inflating: train/1031.png
#   inflating: train/524.png
#   inflating: train/400.png
#   inflating: train/1425.png
#   inflating: train/229.png
#   inflating: train/1110.png
#   inflating: train/674.png
#   inflating: train/441.png
#   inflating: train/590.png
#   inflating: train/621.png
#   inflating: train/764.png
#   inflating: train/1257.png
#   inflating: train/110.png
#   inflating: train/1382.png
#   inflating: train/327.png
#   inflating: train/1175.png
#   inflating: train/1305.png
#   inflating: train/445.png
#   inflating: train/912.png
#   inflating: train/491.png
#   inflating: train/1227.png
#   inflating: train/1417.png
#   inflating: train/433.png
#   inflating: train/903.png
#   inflating: train/936.png
#   inflating: train/768.png
#   inflating: train/1525.png
#   inflating: train/705.png
#   inflating: train/1517.png
#   inflating: train/205.png
#   inflating: train/1347.png
#   inflating: train/153.png
#   inflating: train/123.png
#   inflating: train/1253.png
#   inflating: train/782.png
#   inflating: train/1231.png
#   inflating: train/993.png
#   inflating: train/282.png
#   inflating: train/1502.png
#   inflating: train/1206.png
#   inflating: train/775.png
#   inflating: train/1063.png
#   inflating: train/278.png
#   inflating: train/221.png
#   inflating: train/842.png
#   inflating: train/1126.png
#   inflating: train/188.png
#   inflating: train/418.png
#   inflating: train/306.png
#   inflating: train/1255.png
#   inflating: train/636.png
#   inflating: train/1200.png
#   inflating: train/179.png
#   inflating: train/264.png
#   inflating: train/767.png
#   inflating: train/613.png
#   inflating: train/406.png
#   inflating: train/598.png
#   inflating: train/1214.png
#   inflating: train/732.png
#   inflating: train/1331.png
#   inflating: train/214.png
#   inflating: train/922.png
#   inflating: train/332.png
#   inflating: train/783.png
#   inflating: train/521.png
#   inflating: train/530.png
#   inflating: train/610.png
#   inflating: train/345.png
#   inflating: train/315.png
#   inflating: train/217.png
#   inflating: train/335.png
#   inflating: train/275.png
#   inflating: train/1441.png
#   inflating: train/17.png
#   inflating: train/220.png
#   inflating: train/1401.png
#   inflating: train/870.png
#   inflating: train/503.png
#   inflating: train/320.png
#   inflating: train/737.png
#   inflating: train/602.png
#   inflating: train/322.png
#   inflating: train/241.png
#   inflating: train/677.png
#   inflating: train/781.png
#   inflating: train/467.png
#   inflating: train/651.png
#   inflating: train/250.png
#   inflating: train/1249.png
#   inflating: train/426.png
#   inflating: train/343.png
#   inflating: train/844.png
#   inflating: train/1209.png
#   inflating: train/794.png
#   inflating: train/549.png
#   inflating: train/1300.png
#   inflating: train/8.png
#   inflating: train/71.png
#   inflating: train/772.png
#   inflating: train/1521.png
#   inflating: train/187.png
#   inflating: train/1426.png
#   inflating: train/1372.png
#   inflating: train/460.png
#   inflating: train/156.png
#   inflating: train/266.png
#   inflating: train/1199.png
#   inflating: train/1194.png
#   inflating: train/909.png
#   inflating: train/234.png
#   inflating: train/457.png
#   inflating: train/987.png
#   inflating: train/347.png
#   inflating: train/833.png
#   inflating: train/1398.png
#   inflating: train/319.png
#   inflating: train/943.png
#   inflating: train/293.png
#   inflating: train/30.png
#   inflating: train/240.png
#   inflating: train/1207.png
#   inflating: train/1371.png
#   inflating: train/185.png
#   inflating: train/392.png
#   inflating: train/1306.png
#   inflating: train/50.png
#   inflating: train/882.png
#   inflating: train/124.png
#   inflating: train/261.png
#   inflating: train/632.png
#   inflating: train/317.png
#   inflating: train/1280.png
#   inflating: train/1563.png
#   inflating: train/1510.png
#   inflating: train/394.png
#   inflating: train/144.png
#   inflating: train/1069.png
#   inflating: train/500.png
#   inflating: train/106.png
#   inflating: train/1374.png
#   inflating: train/1070.png
#   inflating: train/1461.png
#   inflating: train/823.png
#   inflating: train/1164.png
#   inflating: train/162.png
#   inflating: train/554.png
#   inflating: train/680.png
#   inflating: train/12.png
#   inflating: train/422.png
#   inflating: train/1062.png
#   inflating: train/676.png
#   inflating: train/869.png
#   inflating: train/120.png
#   inflating: train/1354.png
#   inflating: train/70.png
#   inflating: train/601.png
#   inflating: train/28.png
#   inflating: train/1114.png
#   inflating: train/583.png
#   inflating: train/1193.png
#   inflating: train/484.png
#   inflating: train/465.png
#   inflating: train/502.png
#   inflating: train/92.png
#   inflating: train/199.png
#   inflating: train/499.png
#   inflating: train/1141.png
#   inflating: train/474.png
#   inflating: train/971.png
#   inflating: train/384.png
#   inflating: train/33.png
#   inflating: train/985.png
#   inflating: train/237.png
#   inflating: train/724.png
#   inflating: train/977.png
#   inflating: train/1447.png
#   inflating: train/1503.png
#   inflating: train/784.png
#   inflating: train/938.png
#   inflating: train/949.png
#   inflating: train/305.png
#   inflating: train/355.png
#   inflating: train/766.png
#   inflating: train/984.png
#   inflating: train/835.png
#   inflating: train/872.png
#   inflating: train/118.png
#   inflating: train/1048.png
#   inflating: train/900.png
#   inflating: train/1100.png
#   inflating: train/866.png
#   inflating: train/107.png
#   inflating: train/731.png
#   inflating: train/1413.png
#   inflating: train/232.png
#   inflating: train/1549.png
#   inflating: train/1368.png
#   inflating: train/22.png
#   inflating: train/204.png
#   inflating: train/1239.png
#   inflating: train/527.png
#   inflating: train/1274.png
#   inflating: train/78.png
#   inflating: train/798.png
#   inflating: train/1520.png
#   inflating: train/1177.png
#   inflating: train/1293.png
#   inflating: train/440.png
#   inflating: train/1022.png
#   inflating: train/1471.png
#   inflating: train/1073.png
#   inflating: train/1084.png
#   inflating: train/1289.png
#   inflating: train/1319.png
#   inflating: train/740.png
#   inflating: train/1327.png
#   inflating: train/372.png
#   inflating: train/1339.png
#   inflating: train/108.png
#   inflating: train/834.png
#   inflating: train/57.png
#   inflating: train/288.png
#   inflating: train/748.png
#   inflating: train/312.png
#   inflating: train/323.png
#   inflating: train/249.png
#   inflating: train/986.png
#   inflating: train/686.png
#   inflating: train/788.png
#   inflating: train/1308.png
#   inflating: train/1038.png
#   inflating: train/1455.png
#   inflating: train/1111.png
#   inflating: train/487.png
#   inflating: train/1420.png
#   inflating: train/421.png
#   inflating: train/18.png
#   inflating: train/80.png
#   inflating: train/564.png
#   inflating: train/853.png
#   inflating: train/1057.png
#   inflating: train/382.png
#   inflating: train/1476.png
#   inflating: train/1547.png
#   inflating: train/867.png
#   inflating: train/464.png
#   inflating: train/1041.png
#   inflating: train/643.png
#   inflating: train/39.png
#   inflating: train/134.png
#   inflating: train/1215.png
#   inflating: train/148.png
#   inflating: train/861.png
#   inflating: train/314.png
#   inflating: train/976.png
#   inflating: train/132.png
#   inflating: train/1481.png
#   inflating: train/697.png
#   inflating: train/321.png
#   inflating: train/1396.png
#   inflating: train/409.png
#   inflating: train/533.png
#   inflating: train/836.png
#   inflating: train/498.png
#   inflating: train/1424.png
#   inflating: train/858.png
#   inflating: train/1165.png
#   inflating: train/956.png
#   inflating: train/1544.png
#   inflating: train/1506.png
#   inflating: train/1377.png
#   inflating: train/201.png
#   inflating: train/1241.png
#   inflating: train/1172.png
#   inflating: train/1467.png
#   inflating: train/1029.png
#   inflating: train/1135.png
#   inflating: train/1128.png
#   inflating: train/1435.png
#   inflating: train/1405.png
#   inflating: train/1279.png
#   inflating: train/1079.png
#   inflating: train/1352.png
#   inflating: train/1485.png
#   inflating: train/946.png
#   inflating: train/98.png
#   inflating: train/1285.png
#   inflating: train/1314.png
#   inflating: train/1052.png
#   inflating: train/937.png
#   inflating: train/1577.png
#   inflating: train/1302.png
#   inflating: train/311.png
#   inflating: train/808.png
#   inflating: train/135.png
#   inflating: train/1558.png
#   inflating: train/242.png
#   inflating: train/1463.png
#   inflating: train/1156.png
#   inflating: train/658.png
#   inflating: train/1067.png
#   inflating: train/290.png
#   inflating: train/1323.png
#   inflating: train/755.png
#   inflating: train/666.png
#   inflating: train/817.png
#   inflating: train/370.png
#   inflating: train/1034.png
#   inflating: train/1047.png
#   inflating: train/779.png
#   inflating: train/91.png
#   inflating: train/253.png
#   inflating: train/1149.png
#   inflating: train/1346.png
#   inflating: train/769.png
#   inflating: train/1299.png
#   inflating: train/212.png
#   inflating: train/86.png
#   inflating: train/1037.png
#   inflating: train/414.png
#   inflating: train/1412.png
#   inflating: train/709.png
#   inflating: train/1259.png
#   inflating: train/546.png
#   inflating: train/1158.png
#   inflating: train/667.png
#   inflating: train/37.png
#   inflating: train/258.png
#   inflating: train/26.png
#   inflating: train/1403.png
#   inflating: train/1078.png
#   inflating: train/149.png
#   inflating: train/1006.png
#   inflating: train/595.png
#   inflating: train/227.png
#   inflating: train/1301.png
#   inflating: train/1139.png
#   inflating: train/997.png
#   inflating: train/1477.png
#   inflating: train/1427.png
#   inflating: train/79.png
#   inflating: train/292.png
#   inflating: train/594.png
#   inflating: train/1265.png
#   inflating: train/56.png
#   inflating: train/758.png
#   inflating: train/1251.png
#   inflating: train/386.png
#   inflating: train/496.png
#   inflating: train/895.png
#   inflating: train/477.png
#   inflating: train/492.png
#   inflating: train/270.png
#   inflating: train/450.png
#   inflating: train/972.png
#   inflating: train/1099.png
#   inflating: train/1557.png
#   inflating: train/725.png
#   inflating: train/1479.png
#   inflating: train/1035.png
#   inflating: train/23.png
#   inflating: train/358.png
#   inflating: train/6.png
#   inflating: train/1154.png
#   inflating: train/1171.png
#   inflating: train/318.png
#   inflating: train/490.png
#   inflating: train/665.png
#   inflating: train/668.png
#   inflating: train/1571.png
#   inflating: train/543.png
#   inflating: train/526.png
#   inflating: train/103.png
#   inflating: train/634.png
#   inflating: train/174.png
#   inflating: train/405.png
#   inflating: train/324.png
#   inflating: train/780.png
#   inflating: train/55.png
#   inflating: train/777.png
#   inflating: train/1390.png
#   inflating: train/380.png
#   inflating: train/958.png
#   inflating: train/813.png
#   inflating: train/641.png
#   inflating: train/54.png
#   inflating: train/712.png
#   inflating: train/951.png
#   inflating: train/1493.png
#   inflating: train/359.png
#   inflating: train/346.png
#   inflating: train/1378.png
#   inflating: train/877.png
#   inflating: train/357.png
#   inflating: train/113.png
#   inflating: train/1197.png
#   inflating: train/1250.png
#   inflating: train/1395.png
#   inflating: train/969.png
#   inflating: train/618.png
#   inflating: train/1458.png
#   inflating: train/248.png
#   inflating: train/1462.png
#   inflating: train/1060.png
#   inflating: train/1238.png
#   inflating: train/981.png
#   inflating: train/102.png
#   inflating: train/1003.png
#   inflating: train/52.png
#   inflating: train/66.png
#   inflating: train/1181.png
#   inflating: train/254.png
#   inflating: train/284.png
#   inflating: train/1370.png
#   inflating: train/130.png
#   inflating: train/539.png
#   inflating: train/1211.png
#   inflating: train/1513.png
#   inflating: train/1179.png
#   inflating: train/774.png
#   inflating: train/376.png
#   inflating: train/166.png
#   inflating: train/263.png
#   inflating: train/291.png
#   inflating: train/75.png
#   inflating: train/796.png
#   inflating: train/1113.png
#   inflating: train/182.png
#   inflating: train/1002.png
#   inflating: train/151.png
#   inflating: train/377.png
#   inflating: train/534.png
#   inflating: train/952.png
#   inflating: train/645.png
#   inflating: train/206.png
#   inflating: train/1245.png
#   inflating: train/727.png
#   inflating: train/141.png
#   inflating: train/1030.png
#   inflating: train/887.png
#   inflating: train/1366.png
#   inflating: train/541.png
#   inflating: train/664.png
#   inflating: train/1087.png
#   inflating: train/1432.png
#   inflating: train/1474.png
#   inflating: train/1297.png
#   inflating: train/435.png
#   inflating: train/1292.png
#   inflating: train/1055.png
#   inflating: train/101.png
#   inflating: train/352.png
#   inflating: train/76.png
#   inflating: train/563.png
#   inflating: train/814.png
#   inflating: train/630.png
#   inflating: train/795.png
#   inflating: train/1271.png
#   inflating: train/848.png
#   inflating: train/1263.png
#   inflating: train/251.png
#   inflating: train/396.png
#   inflating: train/995.png
#   inflating: train/257.png
#   inflating: train/1049.png
#   inflating: train/283.png
#   inflating: train/442.png
#   inflating: train/609.png
#   inflating: train/1362.png
#   inflating: train/236.png
#   inflating: train/948.png
#   inflating: train/947.png
#   inflating: train/138.png
#   inflating: train/202.png
#   inflating: train/1576.png
#   inflating: train/647.png
#   inflating: train/295.png
#   inflating: train/1546.png
#   inflating: train/734.png
#   inflating: train/338.png
#   inflating: train/72.png
#   inflating: train/432.png
#   inflating: train/1402.png
#   inflating: train/172.png
#   inflating: train/824.png
#   inflating: train/1387.png
#   inflating: train/40.png
#   inflating: train/1074.png
#   inflating: train/1380.png
#   inflating: train/957.png
#   inflating: train/155.png
#   inflating: train/419.png
#   inflating: train/717.png
#   inflating: train/1392.png
#   inflating: train/525.png
#   inflating: train/1288.png
#   inflating: train/69.png
#   inflating: train/1237.png
#   inflating: train/927.png
#   inflating: train/36.png
#   inflating: train/1325.png
#   inflating: train/1468.png
#   inflating: train/1560.png
#   inflating: train/302.png
#   inflating: train/1393.png
#   inflating: train/1001.png
#   inflating: train/599.png
#   inflating: train/580.png
#   inflating: train/1416.png
#   inflating: train/146.png
#   inflating: train/1384.png
#   inflating: train/762.png
#   inflating: train/700.png
#   inflating: train/785.png
#   inflating: train/902.png
#   inflating: train/964.png
#   inflating: train/820.png
#   inflating: train/1248.png
#   inflating: train/1507.png
#   inflating: train/395.png
#   inflating: train/516.png
#   inflating: train/218.png
#   inflating: train/528.png
#   inflating: train/1011.png
#   inflating: train/1532.png
#   inflating: train/722.png
#   inflating: train/573.png
#   inflating: train/1409.png
# ...
#   inflating: train/1136.png
#   inflating: train/1162.png
#   inflating: train/339.png
#   inflating: train/1541.png
#   inflating: train/1454.png
#   inflating: train/1133.png
#   inflating: train/557.png
#   inflating: train/614.png
#   inflating: train/518.png
#   inflating: train/1404.png
#   inflating: train/698.png
#   inflating: train/568.png
#   inflating: train/807.png
#   inflating: train/1040.png
#   inflating: train/1184.png
#   inflating: train/478.png
#   inflating: train/1365.png
#   inflating: train/1166.png
#   inflating: train/966.png
#   inflating: train/348.png
#   inflating: train/1470.png
#   inflating: train/741.png
#   inflating: train/702.png
#   inflating: train/1068.png
#   inflating: train/633.png
#   inflating: train/379.png
#   inflating: train/287.png
#   inflating: train/809.png
#   inflating: train/119.png
#   inflating: train/170.png
#   inflating: train/443.png
#   inflating: train/455.png
#   inflating: train/1316.png
#   inflating: train/272.png
#   inflating: train/1054.png
#   inflating: train/154.png
#   inflating: train/252.png
#   inflating: train/919.png
#   inflating: train/363.png
#   inflating: train/341.png
#   inflating: train/1204.png
#   inflating: train/1318.png
#   inflating: train/416.png
#   inflating: train/1267.png
#   inflating: train/195.png
#   inflating: train/466.png
#   inflating: train/1508.png
#   inflating: train/1538.png
#   inflating: train/847.png
#   inflating: train/962.png
#   inflating: train/198.png
#   inflating: train/571.png
#   inflating: train/1186.png
#   inflating: train/1469.png
#   inflating: train/532.png
#   inflating: train/825.png
#   inflating: train/486.png
#   inflating: train/1064.png
#   inflating: train/1046.png
#   inflating: train/608.png
#   inflating: train/1423.png
#   inflating: train/0.png
#   inflating: train/862.png
#   inflating: train/1524.png
#   inflating: train/1020.png
#   inflating: train/301.png
#   inflating: train/316.png
#   inflating: train/743.png
#   inflating: train/1566.png
#   inflating: train/744.png
#   inflating: train/139.png
#   inflating: train/114.png
#   inflating: train/1075.png
#   inflating: train/1147.png
#   inflating: train/313.png
#   inflating: train/1353.png
#   inflating: train/2.png
#   inflating: train/578.png
#   inflating: train/828.png
#   inflating: train/940.png
#   inflating: train/42.png
#   inflating: train/829.png
#   inflating: train/837.png
#   inflating: train/924.png
#   inflating: train/207.png
#   inflating: train/74.png
#   inflating: train/945.png
#   inflating: train/1575.png
#   inflating: train/1077.png
#   inflating: train/1516.png
#   inflating: train/129.png
#   inflating: train/553.png
#   inflating: train/816.png
#   inflating: train/1373.png
#   inflating: train/25.png
#   inflating: train/607.png
#   inflating: train/931.png
#   inflating: train/606.png
#   inflating: train/1105.png
#   inflating: train/469.png
#   inflating: train/1169.png
#   inflating: train/1042.png
#   inflating: train/994.png
#   inflating: train/729.png
#   inflating: train/209.png
#   inflating: train/480.png
#   inflating: train/32.png
#   inflating: train/656.png
#   inflating: train/1246.png
#   inflating: train/1472.png
#   inflating: train/905.png
#   inflating: train/1361.png
#   inflating: train/567.png
#   inflating: train/640.png
#   inflating: train/954.png
#   inflating: train/143.png
#   inflating: train/364.png
#   inflating: train/1341.png
#   inflating: train/582.png
#    creating: valid/
#   inflating: valid/1632.png
#   inflating: valid/1624.png
#   inflating: valid/1643.png
#   inflating: valid/1803.png
#   inflating: valid/1840.png
#   inflating: valid/1667.png
#   inflating: valid/1619.png
#   inflating: valid/1853.png
#   inflating: valid/1814.png
#   inflating: valid/1620.png
#   inflating: valid/1801.png
#   inflating: valid/1670.png
#   inflating: valid/1605.png
#   inflating: valid/1692.png
#   inflating: valid/1746.png
#   inflating: valid/1721.png
#   inflating: valid/1585.png
#   inflating: valid/1680.png
#   inflating: valid/1646.png
#   inflating: valid/1854.png
#   inflating: valid/1709.png
#   inflating: valid/1789.png
#   inflating: valid/1717.png
#   inflating: valid/1648.png
#   inflating: valid/1728.png
#   inflating: valid/1603.png
#   inflating: valid/1852.png
#   inflating: valid/1739.png
#   inflating: valid/1788.png
#   inflating: valid/1715.png
#   inflating: valid/1725.png
#   inflating: valid/1733.png
#   inflating: valid/1851.png
#   inflating: valid/1640.png
#   inflating: valid/1868.png
#   inflating: valid/1791.png
#   inflating: valid/1623.png
#   inflating: valid/1810.png
#   inflating: valid/1674.png
#   inflating: valid/1816.png
#   inflating: valid/1669.png
#   inflating: valid/1602.png
#   inflating: valid/1740.png
#   inflating: valid/1786.png
#   inflating: valid/1691.png
#   inflating: valid/1684.png
#   inflating: valid/1718.png
#   inflating: valid/1847.png
#   inflating: valid/1824.png
#   inflating: valid/1857.png
#   inflating: valid/1653.png
#   inflating: valid/1760.png
#   inflating: valid/1804.png
#   inflating: valid/1743.png
#   inflating: valid/1845.png
#   inflating: valid/1719.png
#   inflating: valid/1754.png
#   inflating: valid/1705.png
#   inflating: valid/1858.png
#   inflating: valid/1825.png
#   inflating: valid/1839.png
#   inflating: valid/1671.png
#   inflating: valid/1796.png
#   inflating: valid/1830.png
#   inflating: valid/1799.png
#   inflating: valid/1600.png
#   inflating: valid/1834.png
#   inflating: valid/1832.png
#   inflating: valid/1650.png
#   inflating: valid/1777.png
#   inflating: valid/1860.png
#   inflating: valid/1807.png
#   inflating: valid/1690.png
#   inflating: valid/1730.png
#   inflating: valid/1583.png
#   inflating: valid/1683.png
#   inflating: valid/1708.png
#   inflating: valid/1687.png
#   inflating: valid/1595.png
#   inflating: valid/1621.png
#   inflating: valid/1849.png
#   inflating: valid/1800.png
#   inflating: valid/1714.png
#   inflating: valid/1844.png
#   inflating: valid/1756.png
#   inflating: valid/1767.png
#   inflating: valid/1785.png
#   inflating: valid/1681.png
#   inflating: valid/valid.json
#   inflating: valid/1808.png
#   inflating: valid/1876.png
#   inflating: valid/1699.png
#   inflating: valid/1811.png
#   inflating: valid/1613.png
#   inflating: valid/1741.png
#   inflating: valid/1638.png
#   inflating: valid/1655.png
#   inflating: valid/1861.png
#   inflating: valid/1735.png
#   inflating: valid/1755.png
#   inflating: valid/1753.png
#   inflating: valid/1795.png
#   inflating: valid/1639.png
#   inflating: valid/1855.png
#   inflating: valid/1798.png
#   inflating: valid/1769.png
#   inflating: valid/1589.png
#   inflating: valid/1821.png
#   inflating: valid/1819.png
#   inflating: valid/1752.png
#   inflating: valid/1843.png
#   inflating: valid/1610.png
#   inflating: valid/1627.png
#   inflating: valid/1781.png
#   inflating: valid/1784.png
#   inflating: valid/1677.png
#   inflating: valid/1597.png
#   inflating: valid/1666.png
#   inflating: valid/1776.png
#   inflating: valid/1813.png
#   inflating: valid/1723.png
#   inflating: valid/1578.png
#   inflating: valid/1599.png
#   inflating: valid/1737.png
#   inflating: valid/1630.png
#   inflating: valid/1682.png
#   inflating: valid/1618.png
#   inflating: valid/1727.png
#   inflating: valid/1759.png
#   inflating: valid/1626.png
#   inflating: valid/1856.png
#   inflating: valid/1734.png
#   inflating: valid/1611.png
#   inflating: valid/1783.png
#   inflating: valid/1702.png
#   inflating: valid/1797.png
#   inflating: valid/1750.png
#   inflating: valid/1722.png
#   inflating: valid/1794.png
#   inflating: valid/1775.png
#   inflating: valid/1694.png
#   inflating: valid/1827.png
#   inflating: valid/1711.png
#   inflating: valid/1763.png
#   inflating: valid/1749.png
#   inflating: valid/1629.png
#   inflating: valid/1831.png
#   inflating: valid/1662.png
#   inflating: valid/1614.png
#   inflating: valid/1700.png
#   inflating: valid/1673.png
#   inflating: valid/1837.png
#   inflating: valid/1672.png
#   inflating: valid/1773.png
#   inflating: valid/1688.png
#   inflating: valid/1738.png
#   inflating: valid/1871.png
#   inflating: valid/1587.png
#   inflating: valid/1812.png
#   inflating: valid/1606.png
#   inflating: valid/1588.png
#   inflating: valid/1678.png
#   inflating: valid/1608.png
#   inflating: valid/1865.png
#   inflating: valid/1787.png
#   inflating: valid/1594.png
#   inflating: valid/1668.png
#   inflating: valid/1724.png
#   inflating: valid/1710.png
#   inflating: valid/1836.png
#   inflating: valid/1833.png
#   inflating: valid/1581.png
#   inflating: valid/1591.png
#   inflating: valid/1707.png
#   inflating: valid/1598.png
#   inflating: valid/1665.png
#   inflating: valid/1762.png
#   inflating: valid/1866.png
#   inflating: valid/1732.png
#   inflating: valid/1679.png
#   inflating: valid/1593.png
#   inflating: valid/1609.png
#   inflating: valid/1870.png
#   inflating: valid/1770.png
#   inflating: valid/1663.png
#   inflating: valid/1697.png
#   inflating: valid/1826.png
#   inflating: valid/1731.png
#   inflating: valid/1774.png
#   inflating: valid/1698.png
#   inflating: valid/1806.png
#   inflating: valid/1651.png
#   inflating: valid/1696.png
#   inflating: valid/1676.png
#   inflating: valid/1778.png
#   inflating: valid/1877.png
#   inflating: valid/1867.png
#   inflating: valid/1712.png
#   inflating: valid/1617.png
#   inflating: valid/1859.png
#   inflating: valid/1780.png
#   inflating: valid/1771.png
#   inflating: valid/1820.png
#   inflating: valid/1616.png
#   inflating: valid/1607.png
#   inflating: valid/1764.png
#   inflating: valid/1596.png
#   inflating: valid/1584.png
#   inflating: valid/1695.png
#   inflating: valid/1703.png
#   inflating: valid/1761.png
#   inflating: valid/1873.png
#   inflating: valid/1818.png
#   inflating: valid/1745.png
#   inflating: valid/1686.png
#   inflating: valid/1765.png
#   inflating: valid/1625.png
#   inflating: valid/1829.png
#   inflating: valid/1742.png
#   inflating: valid/1815.png
#   inflating: valid/1658.png
#   inflating: valid/1633.png
#   inflating: valid/1586.png
#   inflating: valid/1766.png
#   inflating: valid/1622.png
#   inflating: valid/1647.png
#   inflating: valid/1729.png
#   inflating: valid/1661.png
#   inflating: valid/1675.png
#   inflating: valid/1689.png
#   inflating: valid/1846.png
#   inflating: valid/1612.png
#   inflating: valid/1660.png
#   inflating: valid/1772.png
#   inflating: valid/1864.png
#   inflating: valid/1615.png
#   inflating: valid/1657.png
#   inflating: valid/1838.png
#   inflating: valid/1704.png
#   inflating: valid/1601.png
#   inflating: valid/1706.png
#   inflating: valid/1842.png
#   inflating: valid/1817.png
#   inflating: valid/1664.png
#   inflating: valid/1579.png
#   inflating: valid/1645.png
#   inflating: valid/1701.png
#   inflating: valid/1805.png
#   inflating: valid/1636.png
#   inflating: valid/1848.png
#   inflating: valid/1862.png
#   inflating: valid/1726.png
#   inflating: valid/1580.png
#   inflating: valid/1828.png
#   inflating: valid/1782.png
#   inflating: valid/1716.png
#   inflating: valid/1582.png
#   inflating: valid/1874.png
#   inflating: valid/1634.png
#   inflating: valid/1654.png
#   inflating: valid/1685.png
#   inflating: valid/1604.png
#   inflating: valid/1792.png
#   inflating: valid/1751.png
#   inflating: valid/1637.png
#   inflating: valid/1841.png
#   inflating: valid/1757.png
#   inflating: valid/1809.png
#   inflating: valid/1790.png
#   inflating: valid/1744.png
#   inflating: valid/1747.png
#   inflating: valid/1869.png
#   inflating: valid/1590.png
#   inflating: valid/1802.png
#   inflating: valid/1872.png
#   inflating: valid/1768.png
#   inflating: valid/1644.png
#   inflating: valid/1822.png
#   inflating: valid/1779.png
#   inflating: valid/1659.png
#   inflating: valid/1693.png
#   inflating: valid/1835.png
#   inflating: valid/1720.png
#   inflating: valid/1649.png
#   inflating: valid/1748.png
#   inflating: valid/1652.png
#   inflating: valid/1635.png
#   inflating: valid/1713.png
#   inflating: valid/1875.png
#   inflating: valid/1736.png
#   inflating: valid/1642.png
#   inflating: valid/1850.png
#   inflating: valid/1641.png
#   inflating: valid/1793.png
#   inflating: valid/1823.png
#   inflating: valid/1758.png
#   inflating: valid/1631.png
#   inflating: valid/1628.png
#   inflating: valid/1592.png
#   inflating: valid/1656.png
#   inflating: valid/1863.png

# %% [markdown]
# # To setup the GPU devices

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# !nvidia-smi
# Out:
# Thu May 28 00:51:55 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8             14W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Setup the transformation for the training and inference phases
#
# Here, we implement preprocessing on the image data we used. In the default setting, the original image size is 150 \* 150 \* 3, we resize it to 128 \* 128 \* 3.
#
# You may change or add new transformations here to implement the data augmentation. Please ensure that the input image size is matched with your model input size.
#
# ## Data augmentation
#
# You can use different transformations to "create" more training data for training your models.
#
# (Image ref: https://www.ibm.com/think/topics/data-augmentation)

# %% [markdown]
# ![data-augmentation-image-augment.png](data:image/png;base64,...)

# %%
train_transform = transforms.Compose([
    ## We resize all images to a specific size, 128 * 128 here
    ## You can resize them into other size, yet you may need to modify the architecture of model to fit the input shape
    transforms.Resize((128, 128)),

    ## TODO: Add your personalized transformation here##
    ## You may reference https://docs.pytorch.org/vision/0.11/transforms.html#automatic-augmentation-transforms

    ## Examples:
    ## transforms.RandomVerticalFlip(p=0.5)   # Filp the image vertically
    ## transforms.RandomHorizontalFlip(p=0.5)  # Filp the image horizontally

    ## Transform the numpy array to the torch tensor
    transforms.ToTensor(),
])

test_transform = transforms.Compose([
    transforms.Resize((128, 128)),

    ## TODO: You may using test-time augmentation here (not necessary if you only want to pass all baselines)
    ## You can implement it if you want.
    transforms.ToTensor(),
])

# %% [markdown]
# ### Example for transformation
#
# We provide some example for transformation here.

# %%
img_path = "./train/0.png"
img = Image.open(img_path).convert("RGB")

transform_list = {
    "Original": transforms.Compose([]),
    "Resize(128,128)": transforms.Resize((128, 128)),
    "RandomCrop(64)": transforms.RandomCrop(64),
    "HorizontalFlip": transforms.RandomHorizontalFlip(p=1.0),
    "VerticalFlip": transforms.RandomVerticalFlip(p=1.0),
    "ColorJitter": transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.1),
    "Grayscale": transforms.Grayscale(num_output_channels=3),
    "GaussianBlur": transforms.GaussianBlur(kernel_size=9)
}

n = len(transform_list)
plt.figure(figsize=(12, 3))
for i, (name, t) in enumerate(transform_list.items()):
    transformed_img = t(img)
    plt.subplot(1, n, i + 1)
    plt.imshow(transformed_img)
    plt.title(name)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Create a table to convert the text label
#
# We don't use the text label directly to train our model. Instead, we first encode the text label into a number representing a specific class (character), and then use them to train models.
#
# Here we have 10 characters in our dataset, the size of this table is 10 of course.

# %%
#############################
## Don't modify this part, or you may get low accuracy on Judgeboi even with good training performance.

label2class = {
    "anon": 0,
    "mutsumi": 1,
    "nyamuchi": 2,
    "rana": 3,
    "sakiko": 4,
    "soyo": 5,
    "taki": 6,
    "tomori": 7,
    "uika": 8,
    "umiri": 9
    ## "mana": 10   ...only appears in few sences...
}

# %% [markdown]
# # Define the custom dataset for this task

# %%
##################################
## If you aren't familiar with Dataset in torch, don't modify this part!!!

class MyGOCharacterDataset(Dataset):
    def __init__(self, json_path, images_dir, transform=None):
        """
        Args:
            json_path (str): Path to the json file with the metadata for this dataset (eg. train.json, valid.json, test.json)
            images_dir (str): Path to the images directory (eg. ./train/)
            transform (callable, optional): The transformation set you create (train_transform)
        """
        self.images_dir = images_dir
        self.transform = transform

        ## load metadata
        with open(json_path, 'r', encoding='utf-8') as f:
            self.metadata = json.load(f)

    def __len__(self):
        return len(self.metadata)

    def __getitem__(self, idx):
        attr = self.metadata[idx]
        img_path = os.path.join(self.images_dir, attr['filename'])
        idx = attr["id"]
        ## Images are opened with RGB channels, 3 channels
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            ## If there is transformations defined, we implement these transformations on our images
            image = self.transform(image)

        if "test" in self.images_dir:
            ## No label for the testing set, so we don't return labels
            return image, idx
        else:
            label = attr['label']
            label = label2class[label]
            return image, label, idx

###########################################

# %% [markdown]
# # Create the subsets for data
#
# We load splited datasets as the training, validation and testing set.

# %%
## You may change the arguments in these dataset depending your environment
## If you follow the sample code in the above steps, you may not modify this part

train_set = MyGOCharacterDataset(
    json_path='./train/train.json',
    images_dir='./train',
    transform=train_transform
)

val_set = MyGOCharacterDataset(
    json_path='./valid/valid.json',
    images_dir='./valid',
    transform=train_transform
)

test_set = MyGOCharacterDataset(
    json_path='./test/test.json',
    images_dir='./test',
    transform=test_transform
)

# %% [markdown]
# # Create Dataloader
#
# We create dataloader to load our data, you can adjust the batch size here, it is also a hyperparameter that may make an impact on the performance.

# %%
train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

# %% [markdown]
# # Define the models
#
# We define and build our own image classifier here. When you build your models, you should keep in mind that **a larger model is not always better than a small model**. Therefore, you aren't expected to build a huge model as a image classifier in this homework.
#
# Also, you may pay attention on **the capacity of your google drive**. If there is no enough space for saving trained model weight, errors may occur during your training phase. As a reminder (or a hint), a model with <= 150 MB is large enough for you to pass the boss baseline.

# %% [markdown]
# ## Linear Model
#
# Here we define a simple linear model as our image classifier.
#
# **This model is so huge (~800 MB), be aware of available space of your google drive!!!**
#
# (Disclaimer: This model is indeed a simple MLP, this model is so huge because the size of image.)
#
#
# ### Let's calculate the number of trainable parameters in this MLP model!!
#
# - First linear layer: 128 \* 128 \* 3 \* 4096 (weight) + 4096 (bias) = 201330688 trainable parameters
# - Second linear layer: 4096 * 512 (weight) + 512 (bias) = 2097664 trainable parameters
# - Last linear layer: 512 * 10 (weight) + 10 (bias) = 5130 trainable parameters
# - Total = 201330688 + 2097664 + 5130 = 203433482 trainable parameters
#
# Each parameter is a 32-bit (4 bytes) floating number, so the model size is:
# $$ \frac{203433482 \cdot 4}{1024 \cdot 1024} ≃ 776.04 (\text{MB})$$
#
# What a huge model!!!

# %%
class MyLinearModel(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        ## TODO: You may modify the linear model here to archieve better performance
        self.simple_linear = nn.Sequential(
            nn.Flatten(),                  # Flatten the image data into a 1D-vector
            nn.Linear(128 * 128 * 3, 4096),       # Fully-connected layer
            nn.ReLU(),                    # Activation function, ReLU here, can change it with other functions
            nn.Linear(4096, 512),
            nn.ReLU(),
            nn.Linear(512, num_classes)          # Using linear layer to map output with number of classes, 10
        )

    def forward(self, x):
        return self.simple_linear(x)

# %% [markdown]
# ## Convolutional Neural Network (CNN)
#
# A convolutional neural network is a model architecture that often used in image-related task.
#
# A filter is used to extract features in the image. In CNN, we train models to learn these filters.
#
# (Image ref: https://www.dragon1.com/terms/convolutional-neural-networks-definition)

# %% [markdown]
# ![convolutional-neural-networks-cnns.png](data:image/png;base64,...)

# %% [markdown]
# ### Let's calculate the number of trainable parameters in this basic CNN model!!
#
# - First convolution layer: 3 \* 32 \* 3 \* 3 = 864  trainable parameters
# - Second convolution layer: 32 \* 64 \* 3 \* 3 = 18432  trainable parameters
# - First linear layer: 64 \* 2 \* 2 \* 32 + 32 = 8224 trainable parameters
# - Second linear layer: 32 \* 10 + 10 = 330 trainable parameters
# - Total: 864 + 18432 + 8224 + 330 = 27850 trainable parameters
#
# Each parameter is a 32-bit (4 bytes) floating number, so the model size is:
# $$ \frac{27850 \cdot 4}{1024 \cdot 1024} ≃ 0.11 (\text{MB})$$
#
# Much smaller than the previous MLP model, right? However, it has much better performance than the MLP model!

# %%
class MyCNNModel(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        ## TODO: Modify the CNN architecture here to get better performance
        ## - Wider
        ## - Deeper
        ## - Not so much downsample to preserve more information in the images (i.e. adjust the kernal size)
        ## - Dropout (nn.Dropout(p), reference: https://docs.pytorch.org/docs/stable/generated/torch.nn.Dropout.html)


        ## Pay attention to the input shape, it may not suit your modified model!!
        ## The default input shape here is [batch_size, 128, 128, 3]
        self.simple_CNN = nn.Sequential(
            nn.Conv2d(3, 32, 3, 1, 1),      # Convolution layer to capture the features in the image
            nn.BatchNorm2d(32),             # Batch normalization
            nn.ReLU(),                      # Activation function
            nn.MaxPool2d(8, 8, 0),          # Maxpooling to downsample the image and only preserve important information

            nn.Conv2d(32, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(8, 8, 0),

            nn.Flatten(),                   # Flatten the image data into a 1D-vector

            nn.Linear(64 * 2 * 2, 32),
            nn.ReLU(),
            nn.Linear(32, num_classes)
        )


        ## TODO: You may use the pre-defined model in this task
        ## You may choose the pre-defined model for yourself
        ## Useful pre-defined model list: https://docs.pytorch.org/vision/main/models.html
        ## Maybe pre-trained weight?

        ## Example:
        ## self.resnet18 = torchvision.models.resnet18(pretrained=False)

        ## You still need to modify the forward() function below to use these pre-defined models on the image
        ## Remember to check the input and output shape of these pre-defined models!

    def forward(self, x):
        return self.simple_CNN(x)

# %% [markdown]
# # Determine the saving directory
#
# You can determine the directory to save your model weight and prediction files.

# %%
## You can change the directory for saving the model weight
save_dir = "./linear/"
os.makedirs(save_dir, exist_ok=True)  # To create the saving directory

# %% [markdown]
# # Fix random seed for reproducibilty
#
# You can fix a random seed to ensure the reproducibility of your experiment. You can also pick another random seed to seek better performance or use multiple models to implement **ensemble** for testing.

# %%
seed = 42   # You may change random seed here
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# %% [markdown]
# # Training loop
#
# This function define how we train the model with images and their corresponding labels. Again, be sure the capacity of your google drive is enough for saving model weight.

# %%
def train_model():
    ## Determine the number of epoch
    num_epochs=20

    model = MyLinearModel().to(device)        ## Initialize the model
    criterion = nn.CrossEntropyLoss()   ## Crossentropy loss function for classification task

    ## We use Adam as our optimizer here, you may change another optimizer
    ## Also, you can change the hyperparameters here, like the learning rate and the decay weight
    optimizer = optim.Adam(model.parameters(), lr=2e-4, weight_decay=1e-5)

    ## For storing the best accuracy on the validation set so far
    best_val_acc = 0

    train_losses, val_losses = [], []
    train_accs, val_accs = [], []
    for epoch in range(num_epochs):
        model.train()       # Set model to the training phase, i.e., be able to optimize the weight in the model

        train_loss = 0
        train_correct = 0

        print("="*20 + f"Epoch {epoch + 1}" + "="*20)
        for images, labels, idx in tqdm(train_loader):              # Iterating the training set with dataloader
            images, labels = images.to(device), labels.to(device)   # Put the training data (images and labels) to GPU
            optimizer.zero_grad()                                   # Clear the gradient computed with previous batch
            outputs = model(images)                                 # Put the image into model to get the result
            loss = criterion(outputs, labels)                       # Compute cross-entropy loss between the label and the model output
            loss.backward()                                         # Back propogation
            optimizer.step()                                        # Optimize the model weight

            train_loss += loss.item()
            train_correct += (outputs.argmax(dim=1) == labels).sum().item()

        ## Compute the training loss and the accuracy for this epoch
        avg_train_loss = train_loss / len(train_loader)
        train_acc = train_correct / len(train_set)
        print(f"Train Loss={avg_train_loss:.4f}, Train Acc={train_acc:.2%}")


        ## Validation phase

        val_correct = 0
        val_loss = 0
        model.eval()    # Set the model in evaluate phase
        with torch.no_grad():   # Set the gradient to zero
            for images, labels, idx in tqdm(val_loader):
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                val_correct += (outputs.argmax(1) == labels).sum().item()

        avg_val_loss = val_loss / len(val_loader)
        val_acc = val_correct / len(val_set)
        print(f"Valid Loss={avg_val_loss:.4f}, Valid Acc={val_acc:.2%}")


        ## Save the model weight with the best accuracy on the validation set
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            save_path = os.path.join(save_dir, 'best_model.pth')
            torch.save(model.state_dict(), save_path)
            print("Model saved (best validation acc.)")

        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)

    epochs = range(1, num_epochs + 1)

    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Validation Loss')
    plt.title('Loss Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(epochs, train_accs, label='Train Acc')
    plt.plot(epochs, val_accs, label='Validation Acc')
    plt.title('Accuracy Curve')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

    import glob
    for path in glob.glob(f"{save_dir}/*.pth"):
        size_mb = os.path.getsize(path) / (1024 * 1024)
        print("Your model size:")
        print(f"{path}: {size_mb:.2f} MB")

# %% [markdown]
# # Training
#
# It may take about a few minutes to half an hour. If your training process is extremely slow, please check whether the GPU is activated or not.

# %%
train_model()   # Training

# %% [markdown]
# # Inference function
#
# In this function, we load the model weight we just trained and use it as an image classifier to classify images into different characters.
#
# After running this function, a json file containing predictions from your model should be produced and downloaded.
#
# You json file must be like such format:
#
# [
#
#   {"id": 1878, "pred": 0},
#   {"id": 1879, "pred": 1},
#   ... (500 entries)
#
# ]

# %%
def inference():
    ## Load the model weight to inference on the testing set
    model = MyLinearModel().to(device)
    ## Be sure that the model weight you loaded has the same architecture of the model you assign!
    ## That is, you cannot load a weight of "MyCNNModel" into a "MyLinearModel"
    model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')), strict=False)

    model.eval()
    results = []
    idx_list = []

    with torch.no_grad():
        for images, idx in tqdm(test_loader):
            images = images.to(device)
            outputs = model(images)  # shape: [batch_size, num_classes]
            preds = outputs.argmax(dim=1).cpu().tolist()  # Get prediction of model

            results.extend(preds)
            idx_list.extend(idx.cpu().tolist())

    ## Remember to modify STUDENT_ID with your own student id!!!
    STUDENT_ID = 'B14902000'

    ########
    ## This part is for producing the prediction file in json format.
    ## If you aren't familir with json, you may not modify this part.

    final_output = []
    for (idx, result) in zip(idx_list, results):
      out = {
          "id": idx,
          "pred": result
      }
      final_output.append(out)

    ## Saving the prediction
    output_path = os.path.join(save_dir, f'{STUDENT_ID.lower()}.json')
    with open(output_path, "w") as f:
        json.dump(final_output, f, indent=4)

    ## Download the output file
    files.download(output_path)

    ########

# %% [markdown]
# # Inferencing
#
# It takes a few seconds to produce the prediction. Again, if the process is extremely slow, you should check whether the GPU is activated or not.

# %%
inference()   # Inferencing

# %% [markdown]
# # Complete your homework

# %% [markdown]
# Yeah! You successfully trained your own models to make prediction on the dataset. Don't forget to submit your prediction file to "judgeboi" to check your performance.

# %% [markdown]
# ![下載.png](data:image/png;base64,...)
